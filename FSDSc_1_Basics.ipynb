# %% [markdown]
# <a href="https://colab.research.google.com/github/drpetros11111/DFSc_AZ/blob/main/FSDSc_1_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
person ="Jose"

# %%
print(f"my name is {person}")
# Out:
# my name is Jose

# %%
d = {'a':123, 'b':456}

# %%
pwd
# Out:
# '/content'

# %% [markdown]
# ###Aggregation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
listy_list = [1, 2, 3]

# %%
listy_list
# Out:
# [1, 2, 3]

# %%
sum(listy_list)
# Out:
# 6

# %%
a1 = np.array([1, 2, 3
               ])

# %%
sum(a1)
# Out:
# 6

# %%
massive_array = np.random.random(100000)
massive_array.size
# Out:
# 100000

# %%
massive_array[:10]
# Out:
# array([0.38540676, 0.55176056, 0.35713349, 0.19642371, 0.6135181 ,
#        0.08335414, 0.06959334, 0.36951692, 0.01894309, 0.00148664])

# %%
# %timeit sum(massive_array)
# %timeit np.sum(massive_array)
# Out:
# 9.04 ms ± 105 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 57.6 µs ± 17.1 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
a2 = np.array([[1, 2, 3.3],
               [4, 5, 6.5]])

# %%
a2
# Out:
# array([[1. , 2. , 3.3],
#        [4. , 5. , 6.5]])

# %%
np.mean(a2)
# Out:
# 3.6333333333333333

# %%
np.max(a2)
# Out:
# 6.5

# %%
np.min(a2)
# Out:
# 1.0

# %%
np.std(a2)
# Out:
# 1.8226964152656422

# %%
np.var(a2)
# Out:
# 3.3222222222222224

# %%
np.sqrt(np.var(a2))
# Out:
# 1.8226964152656422

# %%
high_var_array = np.array([1, 100, 200, 300, 4000, 5000])
low_var_array = np.array([2, 4, 6, 8, 10])

# %%
np.var(high_var_array), np.var(low_var_array)
# Out:
# (4296133.472222221, 8.0)

# %%
np.std(high_var_array), np.std(low_var_array)
# Out:
# (2072.711623024829, 2.8284271247461903)

# %%
np.mean(high_var_array), np.mean(low_var_array)
# Out:
# (1600.1666666666667, 6.0)

# %%
# %matplotlib inline

# %%
plt.hist(high_var_array)
# Out:
# (array([4., 0., 0., 0., 0., 0., 0., 1., 0., 1.]),
#  array([1.0000e+00, 5.0090e+02, 1.0008e+03, 1.5007e+03, 2.0006e+03,
#         2.5005e+03, 3.0004e+03, 3.5003e+03, 4.0002e+03, 4.5001e+03,
#         5.0000e+03]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(low_var_array)
# Out:
# (array([1., 0., 1., 0., 0., 1., 0., 1., 0., 1.]),
#  array([ 2. ,  2.8,  3.6,  4.4,  5.2,  6. ,  6.8,  7.6,  8.4,  9.2, 10. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ###Reshaping & Transposing

# %%
a2.shape
# Out:
# (2, 3)

# %%
np.random.seed(0)
mat1 = np.random.randint(10, size=(5, 3))
mat2 = np.random.randint(10, size=(5, 3))
mat1
# Out:
# array([[5, 0, 3],
#        [3, 7, 9],
#        [3, 5, 2],
#        [4, 7, 6],
#        [8, 8, 1]])

# %%
mat2
# Out:
# array([[6, 7, 7],
#        [8, 1, 5],
#        [9, 8, 9],
#        [4, 3, 0],
#        [3, 5, 0]])

# %%
mat3 = mat1.T

# %%
np.dot(mat3,mat2)
# Out:
# array([[121, 114,  77],
#        [153, 108,  80],
#        [135,  69,  84]])

# %% [markdown]
# #Matplotlib

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot([1, 2,3,4])

# %%
x= [1, 2, 3, 4,]
y =[11, 22, 33, 44]
plt.plot(x,y);

# %% [markdown]
# # 1st ploting method with pyplot API

# %%
fig = plt.figure() #create a figure
ax = fig. add_subplot() #add axes
plt.show()

# %% [markdown]
# #3rd ploting method using the object API

# %%
fig, ax = plt.subplots()
ax.plot(x, y)

# %%
# 1. import the libray & set the magic function to inline
import matplotlib.pyplot as plt
# %matplotlib inline

# 2. Prepare data
x = [1,2, 3, 4]
y = [11, 22, 33, 44]

# 3. Setup the plot
fig, ax = plt.subplots(figsize=(10,10)) #width, height

#4.Plot the data
ax.plot(x,y)

# 5. Customize the plot
ax.set(title = "Simple Plot",
       xlabel = "x-axis",
       ylabel = "y-axis")

# 6. Save the plot
#fig.savefig("images/...")
# Out:
# [Text(0.5, 1.0, 'Simple Plot'), Text(0.5, 0, 'x-axis'), Text(0, 0.5, 'y-axis')]

# %% [markdown]
# #Making figures with NumPy arrays

# %%
# 1. Import NumPy
import numpy as np

# %%
# 2. Create data
x = np.linspace(0, 10, 100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# 3. Plot the data
fig, ax = plt.subplots()
ax.plot(x, x**2)

# %%
# 4. Use the same data to make a scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x))

# %%
# 5. Another scatter plt.plot
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x));

# %%
# 6. Make a plot from a dictionary
nut_butter_prices = {"Almond butter": 10,
                     "Peanut butter": 8,
                     "Cashew butter": 12}

fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(),
       nut_butter_prices.values())

ax.set(title = "Dan's Nut Butter Store",
       xlabel = "Types of Butters",
       ylabel = "Butter prices");

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.values()), list(nut_butter_prices.values()))

ax.set(title ="Dun's Butter Shop",
       xlabel= "Butter Prices",
       ylabel = "Types of Butter")
# Out:
# [Text(0.5, 1.0, "Dun's Butter Shop"),
#  Text(0.5, 0, 'Butter Prices'),
#  Text(0, 0.5, 'Types of Butter')]

# %%
# 7. Make some data for a Histogram
x = np.random.randn(1000)

fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# # Multiple Plots -two options

# %%
# Multiple Plots -first option
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows =2,
                                             ncols =2,
                                             figsize =(10,5))
# Plot on each figure
ax1.plot(x, x/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax4.hist(np.random.randn(100))
# Out:
# (array([ 2.,  9., 15., 20., 17., 15., 11.,  5.,  3.,  3.]),
#  array([-2.11106077, -1.63065197, -1.15024316, -0.66983436, -0.18942555,
#          0.29098325,  0.77139206,  1.25180086,  1.73220967,  2.21261847,
#          2.69302728]),
#  <BarContainer object of 10 artists>)

# %%
# Option 2
fig, ax = plt.subplots(nrows=2,
                       ncols =2,
                       figsize=(10,5))

ax[0,0].plot(x, x/2);
ax[0,1].scatter(np.random.random(10), np.random.random(10));
ax[1,0].bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax[1,1].hist(np.random.randn(1000))
# Out:
# (array([  8.,  25.,  69., 180., 233., 227., 152.,  76.,  24.,   6.]),
#  array([-3.00198548, -2.3939594 , -1.78593332, -1.17790724, -0.56988116,
#          0.03814492,  0.64617101,  1.25419709,  1.86222317,  2.47024925,
#          3.07827533]),
#  <BarContainer object of 10 artists>)
